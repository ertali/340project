# %%
import tensorflow as tf
import tensorflow.keras
import tensorflow.keras.datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow.keras.optimizers
from tensorflow.keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt
import numpy as np

# %%
# Data reading
import pandas as pd
import ast
embeddings = pd.read_csv("better_cleaned_embeddings.csv")
# embeddings['Embedding'] = embeddings['Embedding'].str().replace('[', '').replace(']', '').split(',').astype(float64)
embeddings['Embedding'] = embeddings['Embedding'].apply(ast.literal_eval)

# Convert to numpy array
embedding_matrix = np.vstack(embeddings['Embedding'].values)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

n_samples = len(embedding_matrix)

train_split = int(0.8 * n_samples)
val_split = int(0.9 * n_samples)

X = np.array(embedding_matrix).astype('float32')
y = np.array(embeddings['TLT'].to_numpy()).astype('float32').reshape(-1, 1) # Ensure y is (n_samples, 1)


X_shuffled, y_shuffled = shuffle(X, y)
X_train, X_val, X_test = X_shuffled[:train_split], X_shuffled[train_split:val_split], X_shuffled[val_split:]
y_train, y_val, y_test = y_shuffled[:train_split], y_shuffled[train_split:val_split], y_shuffled[val_split:]
# X_train, X_val, X_test = X[:train_split], X[train_split:val_split], X[val_split:]
# y_train, y_val, y_test = y[:train_split], y[train_split:val_split], y[val_split:]
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)
scaler2 = StandardScaler()
y_train_scaled = scaler2.fit_transform(y_train.reshape(-1, 1))
y_val_scaled = scaler2.transform(y_val.reshape(-1, 1))

# %%
# results = [-2.5]

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(768,)))
model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.3)),
model.add(Dense(256, activation='relu')),
# model.add(Dropout(0.3)),
model.add(Dense(256, activation='relu'))

model.add(Dense(1, activation='linear'))


model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), metrics=['mae'])
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
model.fit(X_train_scaled, y_train_scaled, batch_size=64,
          epochs=150, verbose=1, validation_data=(X_val_scaled, y_val_scaled), callbacks=[early_stopping])

model.evaluate(X_val_scaled, y_val_scaled)

results = pd.DataFrame(X_test_scaled)
# Out:
# Epoch 1/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2600 - mae: 0.8097 - val_loss: 1.7526 - val_mae: 1.0602
# Epoch 2/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0719 - mae: 0.7555 - val_loss: 1.7134 - val_mae: 1.0564
# Epoch 3/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0671 - mae: 0.7404 - val_loss: 1.7050 - val_mae: 1.0559
# Epoch 4/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1029 - mae: 0.7611 - val_loss: 1.7004 - val_mae: 1.0554
# Epoch 5/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0236 - mae: 0.7495 - val_loss: 1.7000 - val_mae: 1.0548
# Epoch 6/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0679 - mae: 0.7392 - val_loss: 1.6987 - val_mae: 1.0547
# Epoch 7/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0938 - mae: 0.7326 - val_loss: 1.6977 - val_mae: 1.0543
# Epoch 8/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0252 - mae: 0.7417 - val_loss: 1.6976 - val_mae: 1.0542
# Epoch 9/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9200 - mae: 0.7167 - val_loss: 1.6973 - val_mae: 1.0542
# Epoch 10/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9040 - mae: 0.7081 - val_loss: 1.6978 - val_mae: 1.0539
# Epoch 11/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9390 - mae: 0.7145 - val_loss: 1.6967 - val_mae: 1.0538
# Epoch 12/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9226 - mae: 0.7053 - val_loss: 1.6964 - val_mae: 1.0538
# Epoch 13/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2272 - mae: 0.7700 - val_loss: 1.6967 - val_mae: 1.0535
# Epoch 14/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9590 - mae: 0.7210 - val_loss: 1.6971 - val_mae: 1.0536
# Epoch 15/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9343 - mae: 0.7073 - val_loss: 1.6972 - val_mae: 1.0535
# Epoch 16/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8891 - mae: 0.6899 - val_loss: 1.6969 - val_mae: 1.0532
# Epoch 17/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9532 - mae: 0.7125 - val_loss: 1.6963 - val_mae: 1.0531
# Epoch 18/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8675 - mae: 0.6921 - val_loss: 1.6979 - val_mae: 1.0536
# Epoch 19/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9491 - mae: 0.7188 - val_loss: 1.6987 - val_mae: 1.0535
# Epoch 20/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0923 - mae: 0.7175 - val_loss: 1.6988 - val_mae: 1.0536
# Epoch 21/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9699 - mae: 0.7014 - val_loss: 1.6992 - val_mae: 1.0535
# Epoch 22/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7917 - mae: 0.6808 - val_loss: 1.6997 - val_mae: 1.0537
# Epoch 23/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8041 - mae: 0.6720 - val_loss: 1.7008 - val_mae: 1.0541
# Epoch 24/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8287 - mae: 0.6812 - val_loss: 1.7010 - val_mae: 1.0539
# Epoch 25/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9012 - mae: 0.6798 - val_loss: 1.7026 - val_mae: 1.0540
# Epoch 26/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9222 - mae: 0.6946 - val_loss: 1.7016 - val_mae: 1.0541
# Epoch 27/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8830 - mae: 0.6899 - val_loss: 1.7026 - val_mae: 1.0543
# Epoch 28/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8765 - mae: 0.6787 - val_loss: 1.7040 - val_mae: 1.0545
# Epoch 29/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9291 - mae: 0.6943 - val_loss: 1.7043 - val_mae: 1.0549
# Epoch 30/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.8130 - mae: 0.6774 - val_loss: 1.7049 - val_mae: 1.0549
# Epoch 31/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8170 - mae: 0.6498 - val_loss: 1.7058 - val_mae: 1.0551
# Epoch 32/150
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8737 - mae: 0.6810 - val_loss: 1.7072 - val_mae: 1.0557
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3212 - mae: 0.9104

# %%
results = pd.DataFrame(y_val)
preds = model.predict(X_val_scaled)
preds_rescaled = scaler2.inverse_transform(preds)

results['predictions'] = preds_rescaled
results
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#             0  predictions
# 0    1.067135     0.036067
# 1    0.006683     0.022320
# 2   -0.554627    -0.151344
# 3    0.470367    -0.235644
# 4    0.769128     0.153382
# ..        ...          ...
# 257  1.574468     0.100523
# 258 -0.033515    -0.072311
# 259 -2.380354    -0.148335
# 260  1.614150     0.079369
# 261 -0.388678     0.022482
#
# [262 rows x 2 columns]

# %%
print(results['predictions'].min())
print(results['predictions'].max())
results['direction'] = (results['predictions'] >= 0)
results['true_direction'] = (results[0] >= 0)
print(len(results[results['direction'] == results['true_direction']]) / len(results))
# Out:
# -0.3981746435165405
# 0.35747504234313965
# 0.48854961832061067

# %%
money = 10000
for index, row in results.iterrows():
  prediction = row['predictions']
  # bet = row['predictions'] * money / 10
  bet = prediction * money * 2
    # Calculate the profit/loss based on actual return (e.g., 10% => 0.10)
  result = bet * (row[0] / 100.0)

  money += result  # Add just the profit/loss
  print(f"prediction: {prediction:.2f}, real: {row[0]:.2f}%, result: {result:.3f}, money: {money:.3f}")
# Out:
# prediction: 0.14, real: 0.08%, result: 2.258, money: 10002.258
# prediction: 0.03, real: 1.47%, result: 10.189, money: 10012.447
# prediction: 0.06, real: -0.05%, result: -0.690, money: 10011.756
# prediction: 0.19, real: -0.11%, result: -4.062, money: 10007.695
# prediction: -0.00, real: -0.29%, result: 0.109, money: 10007.804
# prediction: 0.14, real: 6.72%, result: 190.216, money: 10198.019
# prediction: 0.12, real: 0.04%, result: 1.132, money: 10199.151
# prediction: 0.43, real: 0.13%, result: 11.826, money: 10210.977
# prediction: -0.02, real: 0.13%, result: -0.477, money: 10210.500
# prediction: 0.14, real: 0.45%, result: 12.655, money: 10223.155
# prediction: 0.26, real: 0.60%, result: 32.349, money: 10255.504
# prediction: 0.16, real: 1.80%, result: 59.834, money: 10315.339
# prediction: -0.12, real: -0.34%, result: 8.323, money: 10323.662
# prediction: 0.10, real: -0.81%, result: -17.167, money: 10306.495
# prediction: 0.44, real: 0.51%, result: 46.056, money: 10352.551
# prediction: 0.29, real: 0.53%, result: 32.185, money: 10384.736
# prediction: 0.32, real: 1.06%, result: 70.239, money: 10454.975
# prediction: -0.28, real: -0.15%, result: 9.118, money: 10464.093
# prediction: 0.06, real: -0.81%, result: -9.605, money: 10454.488
# prediction: 0.03, real: 0.13%, result: 0.733, money: 10455.221
# prediction: 0.27, real: -1.41%, result: -78.314, money: 10376.907
# prediction: -0.05, real: -1.34%, result: 14.260, money: 10391.167
# prediction: 0.21, real: 1.02%, result: 45.175, money: 10436.342
# prediction: -0.34, real: 0.47%, result: -33.276, money: 10403.067
# prediction: 0.13, real: -0.87%, result: -23.471, money: 10379.596
# prediction: -0.02, real: 0.13%, result: -0.651, money: 10378.945
# prediction: -0.04, real: -0.23%, result: 1.707, money: 10380.652
# prediction: 0.17, real: 0.51%, result: 17.640, money: 10398.292
# prediction: 0.16, real: 1.11%, result: 37.326, money: 10435.618
# prediction: 0.29, real: 0.00%, result: 0.265, money: 10435.883
# prediction: -0.03, real: -1.61%, result: 9.652, money: 10445.536
# prediction: 0.14, real: 0.38%, result: 11.075, money: 10456.610
# prediction: 0.13, real: -0.35%, result: -9.509, money: 10447.101
# prediction: 0.28, real: 0.14%, result: 8.187, money: 10455.288
# prediction: 0.21, real: 1.61%, result: 71.108, money: 10526.396
# prediction: 0.04, real: -0.56%, result: -4.938, money: 10521.457
# prediction: 0.18, real: 0.26%, result: 9.815, money: 10531.273
# prediction: 0.42, real: -0.44%, result: -39.147, money: 10492.126
# prediction: 0.21, real: -0.26%, result: -11.007, money: 10481.119
# prediction: 0.31, real: 0.85%, result: 55.726, money: 10536.844
# prediction: 0.13, real: -0.88%, result: -23.218, money: 10513.626
# prediction: 0.06, real: 1.74%, result: 22.155, money: 10535.781
# prediction: 0.49, real: -1.64%, result: -168.002, money: 10367.780
# prediction: 0.12, real: -0.10%, result: -2.323, money: 10365.457
# prediction: 0.07, real: 0.28%, result: 4.393, money: 10369.850
# prediction: 0.13, real: 1.02%, result: 27.775, money: 10397.625
# prediction: 0.21, real: -0.49%, result: -21.961, money: 10375.663
# prediction: 0.08, real: 0.65%, result: 10.541, money: 10386.205
# prediction: 0.53, real: -1.91%, result: -210.965, money: 10175.239
# prediction: 0.06, real: -0.17%, result: -2.098, money: 10173.142
# prediction: 0.04, real: 1.51%, result: 13.568, money: 10186.710
# prediction: 0.41, real: 0.72%, result: 60.353, money: 10247.062
# prediction: -0.07, real: 1.10%, result: -16.226, money: 10230.836
# prediction: 0.52, real: 0.20%, result: 21.208, money: 10252.044
# prediction: 0.43, real: 0.46%, result: 40.405, money: 10292.449
# prediction: 0.10, real: -0.90%, result: -18.262, money: 10274.187
# prediction: -0.01, real: 0.17%, result: -0.269, money: 10273.918
# prediction: 0.04, real: -0.19%, result: -1.660, money: 10272.258
# prediction: 0.27, real: 0.35%, result: 19.672, money: 10291.930
# prediction: 0.37, real: 0.25%, result: 19.116, money: 10311.046
# prediction: 0.36, real: -0.02%, result: -1.754, money: 10309.291
# prediction: -0.01, real: -0.13%, result: 0.234, money: 10309.525
# prediction: 0.26, real: -0.88%, result: -46.445, money: 10263.080
# prediction: 0.05, real: 0.96%, result: 9.323, money: 10272.403
# prediction: 0.30, real: 0.50%, result: 31.476, money: 10303.879
# prediction: 0.15, real: -0.34%, result: -10.735, money: 10293.144
# prediction: -0.06, real: -0.67%, result: 8.842, money: 10301.986
# prediction: 0.39, real: 0.55%, result: 43.676, money: 10345.662
# prediction: 0.07, real: -0.09%, result: -1.294, money: 10344.367
# prediction: 0.16, real: 0.58%, result: 18.733, money: 10363.101
# prediction: 0.24, real: 0.86%, result: 41.992, money: 10405.092
# prediction: 0.05, real: 1.52%, result: 15.382, money: 10420.474
# prediction: 0.27, real: 0.94%, result: 52.971, money: 10473.444
# prediction: 0.13, real: -1.52%, result: -42.885, money: 10430.559
# prediction: 0.13, real: -0.08%, result: -2.231, money: 10428.329
# prediction: 0.01, real: 0.52%, result: 0.849, money: 10429.178
# prediction: 0.13, real: 1.08%, result: 29.948, money: 10459.126
# prediction: 0.09, real: 0.58%, result: 11.329, money: 10470.454
# prediction: -0.13, real: 1.43%, result: -39.329, money: 10431.126
# prediction: 0.03, real: -0.66%, result: -4.463, money: 10426.663
# prediction: -0.49, real: 0.13%, result: -13.504, money: 10413.159
# prediction: 0.27, real: -0.07%, result: -4.219, money: 10408.940
# prediction: -0.03, real: -0.32%, result: 2.118, money: 10411.058
# prediction: 0.87, real: -0.60%, result: -108.910, money: 10302.148
# prediction: 0.27, real: -0.09%, result: -4.848, money: 10297.300
# prediction: 0.08, real: -0.32%, result: -5.551, money: 10291.749
# prediction: 0.17, real: -1.44%, result: -49.364, money: 10242.385
# prediction: -0.21, real: -0.25%, result: 10.939, money: 10253.324
# prediction: 0.07, real: 0.59%, result: 8.150, money: 10261.474
# prediction: 0.15, real: -2.20%, result: -69.939, money: 10191.535
# prediction: -0.05, real: -0.71%, result: 7.431, money: 10198.967
# prediction: 0.20, real: 0.86%, result: 34.753, money: 10233.720
# prediction: 0.13, real: -2.06%, result: -56.605, money: 10177.115
# prediction: 0.08, real: -0.18%, result: -2.846, money: 10174.270
# prediction: 0.25, real: 1.87%, result: 93.330, money: 10267.600
# prediction: 0.33, real: 0.87%, result: 57.930, money: 10325.530
# prediction: 0.26, real: -1.40%, result: -74.352, money: 10251.178
# prediction: 0.03, real: 0.76%, result: 4.896, money: 10256.074
# prediction: 0.14, real: 0.78%, result: 22.936, money: 10279.010
# prediction: -0.19, real: 0.23%, result: -8.915, money: 10270.095
# prediction: 0.28, real: -0.51%, result: -29.331, money: 10240.765
# prediction: 0.15, real: -0.26%, result: -7.867, money: 10232.898
# prediction: -0.04, real: -0.31%, result: 2.394, money: 10235.292
# prediction: -0.08, real: 0.08%, result: -1.306, money: 10233.986
# prediction: 0.08, real: -2.05%, result: -32.512, money: 10201.474
# prediction: -0.07, real: 1.41%, result: -19.721, money: 10181.753
# prediction: 0.12, real: 1.20%, result: 30.079, money: 10211.832
# prediction: -0.01, real: -0.05%, result: 0.133, money: 10211.965
# prediction: -0.24, real: -0.23%, result: 11.259, money: 10223.224
# prediction: 0.28, real: -0.20%, result: -11.819, money: 10211.405
# prediction: 0.08, real: -0.12%, result: -2.039, money: 10209.366
# prediction: 0.59, real: -0.04%, result: -5.049, money: 10204.318
# prediction: 0.20, real: -1.45%, result: -58.588, money: 10145.730
# prediction: 0.12, real: -2.12%, result: -49.799, money: 10095.930
# prediction: -0.15, real: 1.23%, result: -38.362, money: 10057.568
# prediction: -0.08, real: 0.03%, result: -0.569, money: 10056.998
# prediction: 0.13, real: 0.88%, result: 22.595, money: 10079.593
# prediction: 0.08, real: 0.44%, result: 6.798, money: 10086.391
# prediction: 0.07, real: 0.55%, result: 7.750, money: 10094.142
# prediction: 0.11, real: 0.02%, result: 0.486, money: 10094.628
# prediction: 0.17, real: -0.68%, result: -22.817, money: 10071.812
# prediction: 0.52, real: 0.03%, result: 2.781, money: 10074.593
# prediction: 0.81, real: -0.03%, result: -5.104, money: 10069.489
# prediction: 0.08, real: 1.31%, result: 21.348, money: 10090.837
# prediction: -0.03, real: 0.55%, result: -2.825, money: 10088.013
# prediction: 0.33, real: -0.11%, result: -7.056, money: 10080.957
# prediction: 0.12, real: -0.59%, result: -14.330, money: 10066.627
# prediction: 0.06, real: 2.42%, result: 30.877, money: 10097.504
# prediction: -0.02, real: 1.75%, result: -6.609, money: 10090.895
# prediction: 0.14, real: 0.55%, result: 15.182, money: 10106.077
# prediction: 0.06, real: -0.01%, result: -0.172, money: 10105.906
# prediction: -0.09, real: 1.56%, result: -29.801, money: 10076.105
# prediction: -0.03, real: 1.24%, result: -6.625, money: 10069.480
# prediction: 0.16, real: 0.04%, result: 1.288, money: 10070.768
# prediction: 0.03, real: 0.25%, result: 1.536, money: 10072.304
# prediction: 0.02, real: 0.12%, result: 0.441, money: 10072.744
# prediction: 0.26, real: 0.03%, result: 1.678, money: 10074.422
# prediction: 0.04, real: 0.51%, result: 3.976, money: 10078.398
# prediction: 0.20, real: 0.33%, result: 13.284, money: 10091.682
# prediction: 0.09, real: 0.45%, result: 8.544, money: 10100.227
# prediction: 0.21, real: 0.80%, result: 34.299, money: 10134.525
# prediction: 0.01, real: 0.31%, result: 0.383, money: 10134.908
# prediction: 0.18, real: 0.24%, result: 9.119, money: 10144.027
# prediction: -0.12, real: 2.64%, result: -64.546, money: 10079.482
# prediction: 0.00, real: 0.00%, result: 0.002, money: 10079.484
# prediction: 0.08, real: -1.44%, result: -24.085, money: 10055.399
# prediction: 0.00, real: 0.02%, result: 0.015, money: 10055.414
# prediction: 0.20, real: -0.12%, result: -4.628, money: 10050.786
# prediction: 0.10, real: -0.37%, result: -7.396, money: 10043.389
# prediction: -0.25, real: -2.14%, result: 106.727, money: 10150.116
# prediction: -0.03, real: 0.54%, result: -3.147, money: 10146.969
# prediction: 0.13, real: -0.67%, result: -18.163, money: 10128.806
# prediction: 0.20, real: -0.11%, result: -4.426, money: 10124.380
# prediction: 0.47, real: 0.76%, result: 72.111, money: 10196.491
# prediction: -0.08, real: -1.35%, result: 21.416, money: 10217.907
# prediction: 0.05, real: 8.55%, result: 85.224, money: 10303.131
# prediction: 0.31, real: 0.13%, result: 8.322, money: 10311.453
# prediction: 0.11, real: -0.19%, result: -4.311, money: 10307.142
# prediction: 0.06, real: 0.13%, result: 1.621, money: 10308.764
# prediction: 0.22, real: 0.33%, result: 15.116, money: 10323.880
# prediction: 0.05, real: 0.39%, result: 4.406, money: 10328.285
# prediction: -0.09, real: 5.84%, result: -112.118, money: 10216.167
# prediction: 0.15, real: 0.37%, result: 11.063, money: 10227.230
# prediction: -0.03, real: -0.61%, result: 3.674, money: 10230.903
# prediction: -0.17, real: -0.19%, result: 6.816, money: 10237.719
# prediction: -0.02, real: 1.40%, result: -5.965, money: 10231.754
# prediction: 0.26, real: -0.17%, result: -8.756, money: 10222.998
# prediction: 0.01, real: -1.77%, result: -2.992, money: 10220.006
# prediction: -0.09, real: -0.36%, result: 6.861, money: 10226.866
# prediction: 0.02, real: 0.86%, result: 2.888, money: 10229.755
# prediction: -0.06, real: -1.11%, result: 14.500, money: 10244.254
# prediction: 0.34, real: 0.57%, result: 39.232, money: 10283.487
# prediction: 0.25, real: 0.37%, result: 18.936, money: 10302.422
# prediction: 0.29, real: 0.48%, result: 28.190, money: 10330.613
# prediction: -0.03, real: -1.80%, result: 9.664, money: 10340.277
# prediction: 0.16, real: -0.41%, result: -13.536, money: 10326.741
# prediction: -0.08, real: -0.11%, result: 1.724, money: 10328.464
# prediction: 0.27, real: 2.23%, result: 123.132, money: 10451.597
# prediction: -0.15, real: -0.07%, result: 2.283, money: 10453.880
# prediction: 0.16, real: 0.32%, result: 10.594, money: 10464.474
# prediction: 0.09, real: 0.41%, result: 7.623, money: 10472.097
# prediction: 0.03, real: -0.57%, result: -3.495, money: 10468.602
# prediction: -0.07, real: 1.10%, result: -15.346, money: 10453.256
# prediction: 0.13, real: -0.36%, result: -9.736, money: 10443.520
# prediction: 0.24, real: -0.06%, result: -2.947, money: 10440.573
# prediction: 0.11, real: 1.68%, result: 37.902, money: 10478.475
# prediction: -0.00, real: -0.27%, result: 0.141, money: 10478.616
# prediction: 0.22, real: 0.17%, result: 7.972, money: 10486.587
# prediction: 0.09, real: 1.05%, result: 19.662, money: 10506.249
# prediction: 0.18, real: 1.16%, result: 43.789, money: 10550.038
# prediction: -0.13, real: -0.71%, result: 18.751, money: 10568.789
# prediction: 0.15, real: -0.36%, result: -11.291, money: 10557.498
# prediction: 0.05, real: 1.07%, result: 11.220, money: 10568.718
# prediction: -0.04, real: -2.73%, result: 21.943, money: 10590.661
# prediction: 0.17, real: -1.70%, result: -60.902, money: 10529.760
# prediction: -0.19, real: 0.11%, result: -4.513, money: 10525.246
# prediction: 0.17, real: 0.16%, result: 5.649, money: 10530.895
# prediction: -0.01, real: 0.64%, result: -1.326, money: 10529.570
# prediction: 0.21, real: -0.62%, result: -27.511, money: 10502.058
# prediction: 0.26, real: 1.26%, result: 67.585, money: 10569.644
# prediction: 0.06, real: 0.80%, result: 10.150, money: 10579.793
# prediction: 0.15, real: -1.44%, result: -45.121, money: 10534.672
# prediction: 0.57, real: 0.01%, result: 1.149, money: 10535.822
# prediction: 0.18, real: 1.02%, result: 38.843, money: 10574.664
# prediction: 0.17, real: -1.60%, result: -58.469, money: 10516.196
# prediction: 0.10, real: 2.30%, result: 48.714, money: 10564.910
# prediction: 0.12, real: 1.29%, result: 32.615, money: 10597.525
# prediction: 0.23, real: -0.29%, result: -14.233, money: 10583.292
# prediction: 0.52, real: -0.73%, result: -80.559, money: 10502.733
# prediction: -0.03, real: 1.02%, result: -6.430, money: 10496.304
# prediction: 0.14, real: 1.32%, result: 38.510, money: 10534.814
# prediction: -0.06, real: -0.30%, result: 3.545, money: 10538.359
# prediction: 0.11, real: 1.46%, result: 32.266, money: 10570.625
# prediction: 0.09, real: 0.19%, result: 3.567, money: 10574.192
# prediction: 0.14, real: 0.40%, result: 11.576, money: 10585.769
# prediction: -0.11, real: 1.70%, result: -39.393, money: 10546.376
# prediction: 0.09, real: 0.17%, result: 3.150, money: 10549.525
# prediction: 0.15, real: -1.17%, result: -36.621, money: 10512.904
# prediction: 0.35, real: 0.15%, result: 10.833, money: 10523.737
# prediction: 0.28, real: -0.23%, result: -13.586, money: 10510.151
# prediction: 0.09, real: -1.85%, result: -35.327, money: 10474.824
# prediction: 0.35, real: -0.23%, result: -16.994, money: 10457.831
# prediction: 0.20, real: 1.49%, result: 61.582, money: 10519.413
# prediction: -0.01, real: 0.60%, result: -1.082, money: 10518.331
# prediction: 0.02, real: 1.44%, result: 5.195, money: 10523.526
# prediction: 0.47, real: -0.02%, result: -2.454, money: 10521.072
# prediction: -0.05, real: 0.04%, result: -0.435, money: 10520.636
# prediction: 0.01, real: -0.83%, result: -2.441, money: 10518.195
# prediction: 0.21, real: 0.23%, result: 9.852, money: 10528.047
# prediction: -0.16, real: 0.04%, result: -1.503, money: 10526.544
# prediction: 0.45, real: 0.17%, result: 16.067, money: 10542.611
# prediction: -0.18, real: -0.39%, result: 14.562, money: 10557.174
# prediction: -0.02, real: 0.56%, result: -2.610, money: 10554.564
# prediction: 0.15, real: 2.10%, result: 65.927, money: 10620.491
# prediction: 0.12, real: 1.35%, result: 35.293, money: 10655.784
# prediction: 0.01, real: -0.73%, result: -2.292, money: 10653.492
# prediction: -0.16, real: 1.40%, result: -47.175, money: 10606.317
# prediction: -0.09, real: 0.77%, result: -13.899, money: 10592.417
# prediction: 0.14, real: 0.01%, result: 0.309, money: 10592.726
# prediction: 0.36, real: -0.32%, result: -24.493, money: 10568.234
# prediction: 0.01, real: 0.81%, result: 1.366, money: 10569.600
# prediction: -0.02, real: 0.31%, result: -1.508, money: 10568.092
# prediction: -0.02, real: 0.07%, result: -0.247, money: 10567.845
# prediction: 0.04, real: 0.18%, result: 1.402, money: 10569.247
# prediction: 0.16, real: 0.76%, result: 25.169, money: 10594.416
# prediction: -0.01, real: 0.20%, result: -0.526, money: 10593.891
# prediction: 0.03, real: 0.49%, result: 2.854, money: 10596.744
# prediction: 0.22, real: 0.05%, result: 2.364, money: 10599.108
# prediction: 0.35, real: 0.51%, result: 36.953, money: 10636.060
# prediction: -0.03, real: 1.23%, result: -7.451, money: 10628.609
# prediction: 0.35, real: 0.28%, result: 20.548, money: 10649.157
# prediction: -0.05, real: -1.42%, result: 16.126, money: 10665.283
# prediction: -0.24, real: -0.46%, result: 23.515, money: 10688.798
# prediction: 0.20, real: -0.79%, result: -33.435, money: 10655.364
# prediction: 0.23, real: -0.69%, result: -34.020, money: 10621.344
# prediction: 0.31, real: -0.06%, result: -3.761, money: 10617.583
# prediction: 0.15, real: 0.16%, result: 4.894, money: 10622.477
# prediction: 0.25, real: 0.26%, result: 13.688, money: 10636.165
# prediction: 0.21, real: 0.20%, result: 9.000, money: 10645.165
# prediction: -0.17, real: 1.96%, result: -72.170, money: 10572.995
# prediction: 0.09, real: 1.21%, result: 21.882, money: 10594.877
# prediction: 0.22, real: -0.12%, result: -5.751, money: 10589.126

# %%
# Classifier version


# Convert to binary classification: 1 = positive change, 0 = non-positive
y = (embeddings['TLT'].values > 0).astype('int32')  # Binary target

# Shuffle and split
X, y = shuffle(X, y, random_state=42)
n_samples = len(X)
train_split = int(0.75 * n_samples)
val_split = int(0.85 * n_samples)

X_train, X_val, X_test = X[:train_split], X[train_split:val_split], X[val_split:]
y_train, y_val, y_test = y[:train_split], y[train_split:val_split], y[val_split:]

# Scale inputs (don't scale outputs for classification)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Build model
model = Sequential([
    Dense(64, activation='relu', input_shape=(768,)),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile model
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    metrics=['accuracy']
)

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

# Train
model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=150,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate
loss, accuracy = model.evaluate(X_val_scaled, y_val, verbose=0)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe67c1653fcc> in <cell line: 0>()
#       3
#       4 # Convert to binary classification: 1 = positive change, 0 = non-positive
# ----> 5 y = (embeddings['TLT'].values > 0).astype('int32')  # Binary target
#       6
#       7 # Shuffle and split
#
# NameError: name 'embeddings' is not defined

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.2 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import keras_tuner as kt

def build_model(hp):
    model = Sequential()

    # Input layer
    model.add(Dense(
        hp.Int('units_input', min_value=64, max_value=256, step=64),
        activation=hp.Choice('activation_input', ['relu', 'tanh']),
        input_shape=(768,)
    ))

    # Hidden layers
    for i in range(hp.Int('num_layers', 1, 3)):  # 1 to 3 layers
        model.add(Dense(
            units=hp.Int(f'units_{i}', min_value=64, max_value=512, step=64),
            activation=hp.Choice(f'activation_{i}', ['relu', 'tanh'])
        ))
        if hp.Boolean(f'dropout_{i}'):
            model.add(Dropout(rate=hp.Float(f'dropout_rate_{i}', min_value=0.1, max_value=0.5, step=0.1)))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Float('lr', 1e-5, 1e-3, sampling='log')),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=30,
    factor=3,
    directory='hyperband_dir',
    project_name='tlt_direction_classifier'
)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

tuner.search(
    X_train_scaled, y_train,
    epochs=50,
    validation_data=(X_val_scaled, y_val),
    callbacks=[early_stopping],
    batch_size=64
)
# Out:
# Trial 90 Complete [00h 00m 09s]
# val_accuracy: 0.5152671933174133
#
# Best val_accuracy So Far: 0.572519063949585
# Total elapsed time: 00h 09m 24s

# %%
# Get the top 15 models
best_models = tuner.get_best_models(num_models=15)

# Evaluate each model
for idx, model in enumerate(best_models):
    test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)
    print(f"Model {idx+1}: Test Accuracy = {test_accuracy:.4f}, Loss = {test_loss:.4f}")
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x7954bf5b6f20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7954bf5b6f20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# Model 1: Test Accuracy = 0.4924, Loss = 0.7615
# Model 2: Test Accuracy = 0.4847, Loss = 0.8964
# Model 3: Test Accuracy = 0.4885, Loss = 1.3622
# Model 4: Test Accuracy = 0.5000, Loss = 0.7453
# Model 5: Test Accuracy = 0.4580, Loss = 0.7455
# Model 6: Test Accuracy = 0.5458, Loss = 0.7717
# Model 7: Test Accuracy = 0.4618, Loss = 2.1464
# Model 8: Test Accuracy = 0.5191, Loss = 0.7235
# Model 9: Test Accuracy = 0.4809, Loss = 0.7577
# Model 10: Test Accuracy = 0.4809, Loss = 0.7279
# Model 11: Test Accuracy = 0.5115, Loss = 0.7064
# Model 12: Test Accuracy = 0.4580, Loss = 0.7060
# Model 13: Test Accuracy = 0.5038, Loss = 0.7033
# Model 14: Test Accuracy = 0.5191, Loss = 0.7001
# Model 15: Test Accuracy = 0.4733, Loss = 0.6981
